# %%
import matplotlib.pyplot as plt
import numpy as np

harga = [15, 25, 30, 35, 40]
label = ['pensil', 'penggaris', 'pulpen', 'buku', 'krayon']

plt.pie(harga, labels=label, autopct='%1.1f%%')
plt.title('visualisasi data vaa')

plt.show()
