# %%
import matplotlib.pyplot as plt
import numpy as np

matrix = np.random.rand(10, 100)
plt.imshow(matrix, cmap='viridis')
plt.title('matrix diva')
plt.colorbar()

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
