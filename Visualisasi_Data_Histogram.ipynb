# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.random.rand(2000)
plt.hist(data, bins=50, color='grey', edgecolor='brown', label='plt.hist()')

plt.title('histogram diva')
plt.legend

plt.show()
